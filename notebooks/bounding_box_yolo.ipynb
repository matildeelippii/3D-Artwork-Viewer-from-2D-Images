# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# %%
model = YOLO('yolo11n.pt')

IMAGE_PATH = "../data/raw_images/img_11.jpg"

#low confidence threshold because object detection on artworks may result challenging
results = model(IMAGE_PATH, conf=0.25)

for result in results:

    annotated_image = result.plot()
    
    annotated_image_rgb = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)
    
   
    plt.figure(figsize=(10, 10))
    plt.imshow(annotated_image_rgb)
    plt.title("Object detection by YOLO11")
    plt.axis('off')
# Out:
# image 1/1 /home/anna/Documenti/Progetto/3D-Artwork-Viewer-from-2D-Images/notebooks/../data/raw_images/img_11.jpg: 512x640 4 persons, 1 sheep, 458.5ms
# Speed: 8.9ms preprocess, 458.5ms inference, 7.2ms postprocess per image at shape (1, 3, 512, 640)
